# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, f_classif
from sklearn.linear_model import LassoCV, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.metrics import accuracy_score, classification_report
import warnings
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=ConvergenceWarning)

data_path = 'E:/Research data/MS/All-based-Sensory.csv'
data_df = pd.read_csv(data_path)

features = data_df.drop(columns=['Visual', 'Image'])
labels = data_df['Visual']

features.replace([np.inf, -np.inf], np.nan, inplace=True)

imputer = SimpleImputer(strategy='median')
features = imputer.fit_transform(features)

scaler = StandardScaler()
features = scaler.fit_transform(features)

features_non_negative = features - features.min(axis=0)

if labels.dtype == 'object':
    encoder = LabelEncoder()
    labels = encoder.fit_transform(labels)

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)
X_train_non_negative, X_test_non_negative = train_test_split(features_non_negative, test_size=0.3, random_state=42)

# %%
def univariate_selection(X, y):
    selector = SelectKBest(score_func=f_classif, k='all')
    selector.fit(X, y)
    scores = selector.scores_
    return scores

def random_forest_importance(X, y):
    model = RandomForestClassifier(random_state=42)
    model.fit(X, y)
    importances = model.feature_importances_
    return importances

def lasso_regularization(X, y):
    lasso = LassoCV(cv=5, random_state=42).fit(X, y)
    importances = np.abs(lasso.coef_)
    return importances

def mutual_info_gain(X, y):
    selector = SelectKBest(score_func=mutual_info_classif, k='all')
    selector.fit(X, y)
    scores = selector.scores_
    return scores

def chi_square(X, y):
    selector = SelectKBest(score_func=chi2, k='all')
    selector.fit(X, y)
    scores = selector.scores_
    return scores

def correlation_with_target(X, y):
    corrs = [np.corrcoef(X[:, i], y)[0, 1] for i in range(X.shape[1])]
    corrs = np.abs(corrs)
    return corrs

def anova_f_value(X, y):
    selector = SelectKBest(score_func=f_classif, k='all')
    selector.fit(X, y)
    scores = selector.scores_
    return scores

def recursive_feature_elimination(X, y):
    model = LogisticRegression(max_iter=1000)
    selector = RFE(model, n_features_to_select=1)
    selector.fit(X, y)
    rankings = selector.ranking_
    return rankings

# %%
ranking_methods = {
    'Univariate Selection': univariate_selection,
    'Random Forest': random_forest_importance,
    'Lasso Regularization': lasso_regularization,
    'Mutual Information Gain': mutual_info_gain,
    'Chi-Square': chi_square,
    'Correlation with Target': correlation_with_target,
    'ANOVA F-value': anova_f_value,
    'RFE': recursive_feature_elimination
}

feature_scores = {}
for method_name, method_func in ranking_methods.items():
    if method_name == 'Chi-Square':
        scores = method_func(X_train_non_negative, y_train)
    else:
        scores = method_func(X_train, y_train)
    feature_scores[method_name] = scores

feature_names = data_df.drop(columns=['Sensory', 'Image']).columns

ranking_dfs = {}
for method_name, scores in feature_scores.items():
    if method_name == 'RFE':
        ranking = scores  
    else:
        ranking = scores.argsort()[::-1].argsort() + 1  

    ranking_df = pd.DataFrame({'Feature': feature_names, 'Rank': ranking})
    ranking_df = ranking_df.sort_values(by='Rank')
    ranking_dfs[method_name] = ranking_df
    print(f"\n\n\n=============== Feature ranking using {method_name} ==========================\n")
    print(ranking_df)

def train_and_evaluate_model(X_train, X_test, y_train, y_test, selected_features, feature_names, num_features):
    X_train_selected = X_train[:, selected_features]
    X_test_selected = X_test[:, selected_features]

    model = LogisticRegression(max_iter=1000)
    model.fit(X_train_selected, y_train)

    y_pred = model.predict(X_test_selected)

    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy using top {num_features} features: {accuracy}")
    print(f"Classification Report using top {num_features} features:")
    print(classification_report(y_test, y_pred))

top_features_counts = [10, 15, 20, 25]

for method_name, method_func in ranking_methods.items():
    print(f"\n\n\n=============== Feature ranking using {method_name} ==========================\n")
    for num_features in top_features_counts:
        selected_features = np.argsort(-feature_scores[method_name])[:num_features]
        train_and_evaluate_model(X_train, X_test, y_train, y_test, selected_features, feature_names, num_features)
# Out:
# =============== Feature ranking using Univariate Selection ==========================
#
#                Feature  Rank
# 22        Motor System     1
# 15       gabor_entropy     2
# 19            contrast     3
# 14        gabor_energy     4
# 17       dissimilarity     5
# 11  Standard Deviation     6
# 21          brightness     7
# 10                Mean     8
# 4        EquivDiameter     9
# 8    Major axis length    10
# 9    Minor axis length    11
# 2             Solidity    12
# 0                 Area    13
# 7           FilledArea    14
# 18         homogeneity    15
# 6               Extent    16
# 1             PA_ratio    17
# 5           ConvexArea    18
# 3          Circularity    19
# 23              Visual    20
# 12          lbp_energy    21
# 13         lbp_entropy    22
# 16         correlation    23
# 20              energy    24
#
#
#
# =============== Feature ranking using Random Forest ==========================
#
#                Feature  Rank
# 19            contrast     1
# 15       gabor_entropy     2
# 20              energy     3
# 13         lbp_entropy     4
# 22        Motor System     5
# 14        gabor_energy     6
# 17       dissimilarity     7
# 12          lbp_energy     8
# 11  Standard Deviation     9
# 16         correlation    10
# 23              Visual    11
# 21          brightness    12
# 18         homogeneity    13
# 10                Mean    14
# 8    Major axis length    15
# 3          Circularity    16
# 1             PA_ratio    17
# 7           FilledArea    18
# 6               Extent    19
# 9    Minor axis length    20
# 2             Solidity    21
# 5           ConvexArea    22
# 4        EquivDiameter    23
# 0                 Area    24
#
#
#
# =============== Feature ranking using Lasso Regularization ==========================
#
#                Feature  Rank
# 14        gabor_energy     1
# 22        Motor System     2
# 23              Visual     3
# 20              energy     4
# 21          brightness     5
# 11  Standard Deviation     6
# 7           FilledArea     7
# 6               Extent     8
# 1             PA_ratio     9
# 9    Minor axis length    10
# 3          Circularity    11
# 10                Mean    12
# 17       dissimilarity    13
# 2             Solidity    14
# 4        EquivDiameter    15
# 5           ConvexArea    16
# 8    Major axis length    17
# 16         correlation    18
# 19            contrast    19
# 12          lbp_energy    20
# 13         lbp_entropy    21
# 18         homogeneity    22
# 15       gabor_entropy    23
# 0                 Area    24
#
#
#
# =============== Feature ranking using Mutual Information Gain ==========================
#
#                Feature  Rank
# 22        Motor System     1
# 17       dissimilarity     2
# 19            contrast     3
# 15       gabor_entropy     4
# 14        gabor_energy     5
# 11  Standard Deviation     6
# 4        EquivDiameter     7
# 21          brightness     8
# 10                Mean     9
# 18         homogeneity    10
# 0                 Area    11
# 23              Visual    12
# 9    Minor axis length    13
# 7           FilledArea    14
# 6               Extent    15
# 1             PA_ratio    16
# 5           ConvexArea    17
# 12          lbp_energy    18
# 13         lbp_entropy    19
# 16         correlation    20
# 8    Major axis length    21
# 20              energy    22
# 3          Circularity    23
# 2             Solidity    24
#
#
#
# =============== Feature ranking using Chi-Square ==========================
#
#                Feature  Rank
# 19            contrast     1
# 22        Motor System     2
# 14        gabor_energy     3
# 17       dissimilarity     4
# 11  Standard Deviation     5
# 21          brightness     6
# 10                Mean     7
# 0                 Area     8
# 7           FilledArea     9
# 5           ConvexArea    10
# 4        EquivDiameter    11
# 8    Major axis length    12
# 9    Minor axis length    13
# 15       gabor_entropy    14
# 3          Circularity    15
# 2             Solidity    16
# 6               Extent    17
# 1             PA_ratio    18
# 23              Visual    19
# 18         homogeneity    20
# 12          lbp_energy    21
# 13         lbp_entropy    22
# 16         correlation    23
# 20              energy    24
#
#
#
# =============== Feature ranking using Correlation with Target ==========================
#
#                Feature  Rank
# 22        Motor System     1
# 15       gabor_entropy     2
# 19            contrast     3
# 14        gabor_energy     4
# 17       dissimilarity     5
# 11  Standard Deviation     6
# 21          brightness     7
# 10                Mean     8
# 4        EquivDiameter     9
# 8    Major axis length    10
# 9    Minor axis length    11
# 2             Solidity    12
# 0                 Area    13
# 7           FilledArea    14
# 18         homogeneity    15
# 6               Extent    16
# 1             PA_ratio    17
# 5           ConvexArea    18
# 3          Circularity    19
# 23              Visual    20
# 12          lbp_energy    21
# 13         lbp_entropy    22
# 16         correlation    23
# 20              energy    24
#
#
#
# =============== Feature ranking using ANOVA F-value ==========================
#
#                Feature  Rank
# 22        Motor System     1
# 15       gabor_entropy     2
# 19            contrast     3
# 14        gabor_energy     4
# 17       dissimilarity     5
# 11  Standard Deviation     6
# 21          brightness     7
# 10                Mean     8
# 4        EquivDiameter     9
# 8    Major axis length    10
# 9    Minor axis length    11
# 2             Solidity    12
# 0                 Area    13
# 7           FilledArea    14
# 18         homogeneity    15
# 6               Extent    16
# 1             PA_ratio    17
# 5           ConvexArea    18
# 3          Circularity    19
# 23              Visual    20
# 12          lbp_energy    21
# 13         lbp_entropy    22
# 16         correlation    23
# 20              energy    24
#
#
#
# =============== Feature ranking using RFE ==========================
#
#                Feature  Rank
# 14        gabor_energy     1
# 20              energy     2
# 22        Motor System     3
# 23              Visual     4
# 17       dissimilarity     5
# 21          brightness     6
# 11  Standard Deviation     7
# 13         lbp_entropy     8
# 18         homogeneity     9
# 10                Mean    10
# 12          lbp_energy    11
# 19            contrast    12
# 6               Extent    13
# 7           FilledArea    14
# 4        EquivDiameter    15
# 0                 Area    16
# 5           ConvexArea    17
# 8    Major axis length    18
# 15       gabor_entropy    19
# 9    Minor axis length    20
# 1             PA_ratio    21
# 3          Circularity    22
# 16         correlation    23
# 2             Solidity    24
#
#
#
# =============== Feature ranking using Univariate Selection ==========================
#
# Accuracy using top 10 features: 0.6444444444444445
# Classification Report using top 10 features:
#               precision    recall  f1-score   support
#
#            0       0.67      0.81      0.73        81
#            1       0.58      0.39      0.47        54
#
#     accuracy                           0.64       135
#    macro avg       0.62      0.60      0.60       135
# weighted avg       0.63      0.64      0.63       135
#
# Accuracy using top 15 features: 0.6962962962962963
# Classification Report using top 15 features:
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77        81
#            1       0.68      0.46      0.55        54
#
#     accuracy                           0.70       135
#    macro avg       0.69      0.66      0.66       135
# weighted avg       0.69      0.70      0.68       135
#
# Accuracy using top 20 features: 0.7925925925925926
# Classification Report using top 20 features:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84        81
#            1       0.82      0.61      0.70        54
#
#     accuracy                           0.79       135
#    macro avg       0.80      0.76      0.77       135
# weighted avg       0.80      0.79      0.79       135
#
# Accuracy using top 25 features: 0.7777777777777778
# Classification Report using top 25 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
#
#
#
# =============== Feature ranking using Random Forest ==========================
#
# Accuracy using top 10 features: 0.725925925925926
# Classification Report using top 10 features:
#               precision    recall  f1-score   support
#
#            0       0.73      0.86      0.79        81
#            1       0.72      0.52      0.60        54
#
#     accuracy                           0.73       135
#    macro avg       0.72      0.69      0.70       135
# weighted avg       0.72      0.73      0.72       135
#
# Accuracy using top 15 features: 0.7851851851851852
# Classification Report using top 15 features:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.83        81
#            1       0.80      0.61      0.69        54
#
#     accuracy                           0.79       135
#    macro avg       0.79      0.76      0.76       135
# weighted avg       0.79      0.79      0.78       135
#
# Accuracy using top 20 features: 0.7777777777777778
# Classification Report using top 20 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
# Accuracy using top 25 features: 0.7777777777777778
# Classification Report using top 25 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
#
#
#
# =============== Feature ranking using Lasso Regularization ==========================
#
# Accuracy using top 10 features: 0.7777777777777778
# Classification Report using top 10 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
# Accuracy using top 15 features: 0.7777777777777778
# Classification Report using top 15 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
# Accuracy using top 20 features: 0.7777777777777778
# Classification Report using top 20 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
# Accuracy using top 25 features: 0.7777777777777778
# Classification Report using top 25 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
#
#
#
# =============== Feature ranking using Mutual Information Gain ==========================
#
# Accuracy using top 10 features: 0.6962962962962963
# Classification Report using top 10 features:
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77        81
#            1       0.68      0.46      0.55        54
#
#     accuracy                           0.70       135
#    macro avg       0.69      0.66      0.66       135
# weighted avg       0.69      0.70      0.68       135
#
# Accuracy using top 15 features: 0.7777777777777778
# Classification Report using top 15 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
# Accuracy using top 20 features: 0.7777777777777778
# Classification Report using top 20 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
# Accuracy using top 25 features: 0.7777777777777778
# Classification Report using top 25 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
#
#
#
# =============== Feature ranking using Chi-Square ==========================
#
# Accuracy using top 10 features: 0.6296296296296297
# Classification Report using top 10 features:
#               precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71        81
#            1       0.55      0.44      0.49        54
#
#     accuracy                           0.63       135
#    macro avg       0.61      0.60      0.60       135
# weighted avg       0.62      0.63      0.62       135
#
# Accuracy using top 15 features: 0.6518518518518519
# Classification Report using top 15 features:
#               precision    recall  f1-score   support
#
#            0       0.67      0.83      0.74        81
#            1       0.60      0.39      0.47        54
#
#     accuracy                           0.65       135
#    macro avg       0.64      0.61      0.61       135
# weighted avg       0.64      0.65      0.63       135
#
# Accuracy using top 20 features: 0.7925925925925926
# Classification Report using top 20 features:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84        81
#            1       0.82      0.61      0.70        54
#
#     accuracy                           0.79       135
#    macro avg       0.80      0.76      0.77       135
# weighted avg       0.80      0.79      0.79       135
#
# Accuracy using top 25 features: 0.7777777777777778
# Classification Report using top 25 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
#
#
#
# =============== Feature ranking using Correlation with Target ==========================
#
# Accuracy using top 10 features: 0.6444444444444445
# Classification Report using top 10 features:
#               precision    recall  f1-score   support
#
#            0       0.67      0.81      0.73        81
#            1       0.58      0.39      0.47        54
#
#     accuracy                           0.64       135
#    macro avg       0.62      0.60      0.60       135
# weighted avg       0.63      0.64      0.63       135
#
# Accuracy using top 15 features: 0.6962962962962963
# Classification Report using top 15 features:
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77        81
#            1       0.68      0.46      0.55        54
#
#     accuracy                           0.70       135
#    macro avg       0.69      0.66      0.66       135
# weighted avg       0.69      0.70      0.68       135
#
# Accuracy using top 20 features: 0.7925925925925926
# Classification Report using top 20 features:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84        81
#            1       0.82      0.61      0.70        54
#
#     accuracy                           0.79       135
#    macro avg       0.80      0.76      0.77       135
# weighted avg       0.80      0.79      0.79       135
#
# Accuracy using top 25 features: 0.7777777777777778
# Classification Report using top 25 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
#
#
#
# =============== Feature ranking using ANOVA F-value ==========================
#
# Accuracy using top 10 features: 0.6444444444444445
# Classification Report using top 10 features:
#               precision    recall  f1-score   support
#
#            0       0.67      0.81      0.73        81
#            1       0.58      0.39      0.47        54
#
#     accuracy                           0.64       135
#    macro avg       0.62      0.60      0.60       135
# weighted avg       0.63      0.64      0.63       135
#
# Accuracy using top 15 features: 0.6962962962962963
# Classification Report using top 15 features:
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77        81
#            1       0.68      0.46      0.55        54
#
#     accuracy                           0.70       135
#    macro avg       0.69      0.66      0.66       135
# weighted avg       0.69      0.70      0.68       135
#
# Accuracy using top 20 features: 0.7925925925925926
# Classification Report using top 20 features:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84        81
#            1       0.82      0.61      0.70        54
#
#     accuracy                           0.79       135
#    macro avg       0.80      0.76      0.77       135
# weighted avg       0.80      0.79      0.79       135
#
# Accuracy using top 25 features: 0.7777777777777778
# Classification Report using top 25 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
#
#
#
#
# =============== Feature ranking using RFE ==========================
#
# Accuracy using top 10 features: 0.6444444444444445
# Classification Report using top 10 features:
#               precision    recall  f1-score   support
#
#            0       0.66      0.85      0.74        81
#            1       0.60      0.33      0.43        54
#
#     accuracy                           0.64       135
#    macro avg       0.63      0.59      0.59       135
# weighted avg       0.63      0.64      0.62       135
#
# Accuracy using top 15 features: 0.6962962962962963
# Classification Report using top 15 features:
#               precision    recall  f1-score   support
#
#            0       0.69      0.89      0.78        81
#            1       0.71      0.41      0.52        54
#
#     accuracy                           0.70       135
#    macro avg       0.70      0.65      0.65       135
# weighted avg       0.70      0.70      0.67       135
#
# Accuracy using top 20 features: 0.7333333333333333
# Classification Report using top 20 features:
#               precision    recall  f1-score   support
#
#            0       0.71      0.93      0.81        81
#            1       0.80      0.44      0.57        54
#
#     accuracy                           0.73       135
#    macro avg       0.76      0.69      0.69       135
# weighted avg       0.75      0.73      0.71       135
#
# Accuracy using top 25 features: 0.7777777777777778
# Classification Report using top 25 features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        81
#            1       0.80      0.59      0.68        54
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.75      0.76       135
# weighted avg       0.78      0.78      0.77       135
